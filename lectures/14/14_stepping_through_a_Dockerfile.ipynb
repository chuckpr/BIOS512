# %% [markdown]
# # Dockerfiles

# %% [markdown]
# # What is "Docker"?

# %% [markdown]
# <img src="https://www.docker.com/sites/default/files/d8/styles/large/public/2018-11/container-what-is-container.png" style="width: 600px" />

# %% [markdown]
# # But why?

# %% [markdown]
# - it's the future... and the present.

# %% [markdown]
# - portable, reproducible data _science_.

# %% [markdown]
# - ultimately it's enhances productivity for the community.
#  - easier for tool developers
#  - easier for data scientists

# %% [markdown]
# ## Inherit from another image

# %% [markdown]
# `FROM rocker/binder:3.6.0`

# %% [markdown]
# `<organization>/:<tag>`

# %% [markdown]
# [https://github.com/rocker-org/binder](https://github.com/rocker-org/binder)

# %% [markdown]
# ## Add elements

# %% [markdown]
# [https://github.com/chuckpr/BIOS512/blob/master/Dockerfile](https://github.com/chuckpr/BIOS512/blob/master/Dockerfile)

# %% [markdown]
# Packages from online package repositories:
#
# E.g.
# ```Dockerfile
# RUN pip3 install jupyterlab=1.0.9
# ```

# %% [markdown]
# Copy files from the "host" to the image:
#
# ```Dockerfile
# COPY <from host> <destination in image>
# ```

# %% [markdown]
# ```Dockerfile
# COPY in-class-exercises ${HOME}/in-class-exercises
# COPY assignments ${HOME}/assignments
# ```

# %% [markdown]
# ```Dockerfile
# COPY install.R ./
# ```

# %% [markdown]
# # Build "image"

# %% [markdown]
# # Run "container"

# %% [markdown]
# - the container is a running instance of the image.
# - can multiple containers running from a single instance.

# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/chuckpr/BIOS512/master)

# %% [markdown]
# What happens if you launch **binder** in two separate tabs?
