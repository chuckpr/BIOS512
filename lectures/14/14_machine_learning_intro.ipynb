# %% [markdown]
# # Maching Learning

# %% [markdown]
# What is machine learning?

# %% [markdown]
# ![image.png](attachment:8353da84-9e59-4211-938b-358f1a230727.png)

# %% [markdown]
# ![](https://cdn.vox-cdn.com/thumbor/AwKSiDyDnwy_qoVdLPyoRPUPo00=/39x0:3111x2048/1400x1400/filters:focal(39x0:3111x2048):format(png)/cdn.vox-cdn.com/uploads/chorus_image/image/49901753/netflixlogo.0.0.png)

# %% [markdown]
# ![image.png](attachment:75f3a312-bdf1-4bff-bcd9-63da4ed706e0.png)

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# Things to remember:
# - You cannot transcend your training data
# - Do not use test data to optimize your model
# - Think of the goal as getting an accurate estimate of how the model would perform. *Dont't think of the goal as building a good model (although this is nice)*

# %% [markdown]
# # Machine learning example

# %% [markdown]
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# **Given the data can we predict abalone age and sex?**
