# %%
library("tidyverse")
options(repr.plot.width = 4, repr.plot.height = 3, repr.plot.res = 300)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
mpg %>% head
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point()

p
# Out:
# plot without title

# %% [markdown]
# - axis.labels
# - title
# - axis text
# - background color
# - grid and ticks
# - margin

# %% [markdown]
# ## `labs`

# %%
options(repr.plot.width = 5.5, repr.plot.height = 3)
p = ggplot(mpg, aes(x = displ, y = hwy, color = class))

p = p + geom_point()

p = p + labs(x = "Displacement, mL", y = "Highway, MPG", color = "vehicle\nclass")

p
# Out:
# plot without title

# %% [markdown]
# - `axis.title`

# %% [markdown]
# - if we're changing text we use `element_text`

# %%
# ?element_text

# %%
options(repr.plot.width = 4, repr.plot.height = 3)

p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point()

p = p + labs(x = "Displacement, mL", y = "Highway, MPG")

p = p + theme(axis.title.x = element_text(color = 'red'))

p
# Out:
# plot without title

# %% [markdown]
# ## axis "text" (some times referred to as "ticks labels")

# %%
p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point()

p = p + labs(x = "Displacement, mL", y = "Highway, MPG")

p = p + theme(axis.text = element_text(color = "orange"))

p
# Out:
# plot without title

# %% [markdown]
# ## "plot" and the "panel"

# %% [markdown]
# - for plot and panel we use `element_rect`

# %%
p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point()

p = p + labs(x = "Displacement, mL", y = "Highway, MPG")

p = p + theme(panel.background = element_rect(fill = 'lightblue')) # try with panel

p
# Out:
# plot without title

# %% [markdown]
# ## "grid" and "ticks"

# %% [markdown]
# - for the grid and the ticks we use `element_line`

# %%
p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point()

p = p + labs(x = "Displacement, mL", y = "Highway, MPG")

p = p + theme(
    axis.ticks.x = element_line(color = 'blue'),
    axis.title = element_blank(),
    panel.grid.major = element_line(color = "gray90"),
    panel.background = element_blank()
) # try with axis.ticks

p
# Out:
# plot without title

# %% [markdown]
# - use `element_blank` to turn something off

# %%
## margins

# %% [markdown]
# - to adjust margins use `margin`
# - the order is top, right, bottom, left (i.e. clockwise starting from the top)

# %%
?margin

# %%
p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point()

p = p + labs(x = "Displacement, mL", y = "Highway, MPG")

p = p + theme(
    axis.title.x = element_text(margin = margin(t = 12)),
    axis.title.y = element_text(margin = margin(r = 12))
) # try with panel

p
# Out:
# plot without title

# %% [markdown]
# <img src="07_dark_mode.png" style="width: 600px" />

# %%
p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point()

p = p + labs(x = "Displacement, mL", y = "Highway, MPG")

p = p + theme_bw()

p = p + theme(
    axis.title.x = element_text(margin = margin(t = 12)),
    axis.title.y = element_text(margin = margin(r = 12))
) # try with panel

p
# Out:
# plot without title
