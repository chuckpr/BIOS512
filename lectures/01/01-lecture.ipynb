# %%
from IPython.display import IFrame, Image

# %% [markdown]
# # Welcome to Data Science Basics!
#
# ## BIOS512

# %% [markdown]
# ### My name is Chuck Pepe-Ranney (please call me Chuck)

# %%
Image(
    url=('https://49vp4h2c1u8330kjey1hhz4d-wpengine.netdna-ssl.com/wp-content'
         '/uploads/sites/158/2018/11/mines-side-stack_4cp.png'),
    width=700
)
# Out:
# <img src="https://49vp4h2c1u8330kjey1hhz4d-wpengine.netdna-ssl.com/wp-content/uploads/sites/158/2018/11/mines-side-stack_4cp.png" width="700"/>

# %%
Image(
    'http://www.rpgroup.caltech.edu/mbl_pboc/images/mbl.jpg',
    width=600
)

# %% [markdown]
# ## [LifeEdit Therapeutics](https://www.lifeeditinc.com/)

# %%
Image(
    ('https://www.genome.gov/sites/default/files/'
     'inline-images/Sequencing_Cost_per_Megabase_August2019.jpg'),
    width=700
)

# %% [markdown]
# ## [Lots of data to work with](https://covid19.ncdhhs.gov/dashboard)

# %% [markdown]
# # This will be a fun class.

# %% [markdown]
# # Course website
#
# > https://github.com/chuckpr/BIOS512

# %% [markdown]
# > We're going to learn about exciting technology that empowers **you** to unlock data and build data-driven narratives.

# %% [markdown]
# | Assignments | Points/Percentages |
# | --- | ---: |
# | (approximately) Weekly exercises | 75 |
# | Final project/exam | 20 |
# | Participation | 5 |

# %%
Image(
    'https://p.kindpng.com/picc/s/128-1280187_github-logo-png-github-transparent-png.png',
    width=700
)

# %%
IFrame('https://mybinder.org', width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://mybinder.org"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# [Binder example](http://mybinder.org/v2/gh/binder-examples/r/master?filepath=index.ipynb)

# %%
Image(
    ('https://upload.wikimedia.org/wikipedia/commons/'
     'thumb/3/38/Jupyter_logo.svg/1200px-Jupyter_logo.svg.png'), 
    width=400
)

# %% [markdown]
# I do, you do, we do

# %% [markdown]
# - Data **visualization**
# - Data **wrangling**
# - Data **exploration**
#
# <img src='https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2017/05/R_logo.svg_.png' width=200 />

# %%
Image(
    'https://www.tidyverse.org/images/hex-tidyverse.png',
    width=400
)

# %% [markdown]
# # Basic syntax for wrangling and visualizing data

# %%
Image(
    ('https://d33wubrfki0l68.cloudfront.net/'
    '0ab849ed51b0b866ef6895c253d3899f4926d397/dbf0f/images/hex-ggplot2.png'),
    width=400
)

# %% [markdown]
# [https://twitter.com/geokaramanis/status/1287078182139629572?s=20](https://twitter.com/geokaramanis/status/1287078182139629572?s=20)

# %%
Image(
    'https://raw.githubusercontent.com/rstudio/hex-stickers/master/PNG/tidymodels.png',
    width=400
)

# %% [markdown]
# # Some other stuff..

# %%
Image(
    ('https://slackhq.com/wp-content/uploads/2019/01/'
     '2019-01_BrandRefresh_slack-brand-refresh_header-1.png'),
      width=500
)

# %%
IFrame('https://r4ds.had.co.nz', width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://r4ds.had.co.nz"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Dev*Sci*Ops

# %% [markdown]
# ```yaml
# FROM jupyter/datascience-notebook:2ce7c06a61a1
#
# RUN conda install r-tidyverse --channel conda-forge
# ```

# %%
Image(
    url='https://git-scm.com/images/logos/downloads/Git-Logo-2Color.png',
    width=700
)
# Out:
# <img src="https://git-scm.com/images/logos/downloads/Git-Logo-2Color.png" width="700"/>

# %% [markdown]
# # The *Polyglot* approach

# %%
class Tweet(object):
    def __init__(self, embed_str=None):
        self.embed_str = embed_str

    def _repr_html_(self):
        return self.embed_str

s = ("""
<blockquote class="twitter-tweet"><p lang="en" dir="ltr">
Polyglot Data Science: Python, R, 
<a href="https://twitter.com/JuliaLanguage?ref_src=twsrc%5Etfw">@JuliaLanguage</a> 
and Fortran cooperating in-process, through 
<a href="https://twitter.com/IPythonDev?ref_src=twsrc%5Etfw">@IPythonDev</a>; 
demo code:
<a href="https://t.co/93tIyWY68k">https://t.co/93tIyWY68k</a>
<br><br>
Language wars among open tools are pointless, 
they complement each other.<br><br>Video/slides of the talk 
<a href="https://twitter.com/UCBIDS?ref_src=twsrc%5Etfw">@UCBIDS</a>: 
<a href="https://t.co/voEKY5FUVj">https://t.co/voEKY5FUVj</a>
</p>&mdash; Fernando Perez (@fperez_org) 
<a href="https://twitter.com/fperez_org/status/987882327760977921?ref_src=twsrc%5Etfw">April 22, 2018</a>
</blockquote> 
<script async src="https://platform.twitter.com/widgets.js" charset="utf-8">
</script>
""")

# %%
# taken from http://jakevdp.github.io/blog/2017/03/03/reproducible-data-analysis-in-jupyter/
from IPython.display import YouTubeVideo
def embed_video(index, playlist='PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ'):
    return YouTubeVideo('', index=index - 1, list=playlist, width=600, height=350)

# %%
embed_video(1)
# Out:
#         <iframe
#             width="600"
#             height="350"
#             src="https://www.youtube.com/embed/?index=0&list=PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('https://juliasilge.com/blog/texas-opioids/', width=800, height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="https://juliasilge.com/blog/texas-opioids/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
Tweet(s)
# Out:
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">
# Polyglot Data Science: Python, R,
# <a href="https://twitter.com/JuliaLanguage?ref_src=twsrc%5Etfw">@JuliaLanguage</a>
# and Fortran cooperating in-process, through
# <a href="https://twitter.com/IPythonDev?ref_src=twsrc%5Etfw">@IPythonDev</a>;
# demo code:
# <a href="https://t.co/93tIyWY68k">https://t.co/93tIyWY68k</a>
# <br><br>
# Language wars among open tools are pointless,
# they complement each other.<br><br>Video/slides of the talk
# <a href="https://twitter.com/UCBIDS?ref_src=twsrc%5Etfw">@UCBIDS</a>:
# <a href="https://t.co/voEKY5FUVj">https://t.co/voEKY5FUVj</a>
# </p>&mdash; Fernando Perez (@fperez_org)
# <a href="https://twitter.com/fperez_org/status/987882327760977921?ref_src=twsrc%5Etfw">April 22, 2018</a>
# </blockquote>
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8">
# </script>

# %% [markdown]
# # Survey
#
# > https://forms.gle/5Rcy3NrCY1J2X2nH8

# %% [markdown]
# # Please sign on to the course Slack!
