# %% [markdown]
# ## Key concepts:
#
# 1. **Encodings, mapping data to chart elements**
# 1. Scales ("domain" to "range")
# 1. Theme
# 1. Stats

# %% [markdown]
# `RStudio` [GGPlot2 cheat sheet](https://www.rstudio.com/resources/cheatsheets/)

# %%
library('palmerpenguins')
library('tidyverse')
# Out:
# ── Attaching packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
penguins |> head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
# What does one point represent?

options(repr.plot.res = 250, repr.plot.height = 3, repr.plot.width = 5) 

p = ggplot(penguins, aes(x = bill_length_mm, y = flipper_length_mm, color = species)) + 
    geom_point(na.rm = T) +
    scale_color_brewer(palette = 'Set2') +
    labs(x = 'Bill length, mm', y = 'Flipper length, mm', color = 'Species')

p
# Out:
# plot without title

# %% [markdown]
# ## GGPlot2 intro

# %% [markdown]
# 1. Start with the `ggplot` function
# 1. Encodings are defined with the `aes` instuction/function
# 1. We pass in the data as the first "argument"
# 1. We pass encodings to `ggplot` in the second argument
# 1. Capture the output

# %%
ggplot(penguins, aes(y = species))
# Out:
# plot without title

# %%
# ggplot(penguins, aes(y = species)) + geom_point()

# %% [markdown]
# Aesthetic encodings point at columns in our data.

# %% [markdown]
# <div style="display:flex;justify-content:center;">
# <img src="bar_chart.png" style="width: 600px" />
# </div>

# %% [markdown]
# What would the encodings be for the chart above 🔝?
#
# - `X`?
# - `Y`?

# %%
# Bar chart code here...
